# %% [markdown]
# # UrbanStyle — nädal 7 grupitöö
#
# ## Nädala teema
#
# **Python ja pandas: RFM-kliendisegmenteerimine**
#
# ## Nädala eesmärk
#
# Nädala eesmärk on kasutada Pythonit ja pandas't UrbanStyle'i kliendiandmete analüüsimiseks, et:
#
# - laadida ja ühendada vajalikud andmed;
# - puhastada analüüsiks kasutatav andmestik;
# - arvutada klientidele RFM-näitajad;
# - jaotada kliendid segmentidesse;
# - visualiseerida tulemused;
# - anda Markole andmetel põhinev äritõlgendus ja tegevussoovitused.
#
# ## Rollid
#
# | Roll | Rolli pealkiri | Vastutaja |
# |---|---|---|
# | **Roll A** | Data Loading — andmete laadimine ja ühendamine | **Natalia** |
# | **Roll B** | Data Cleaning — andmete puhastamine | **Olga** |
# | **Roll C** | RFM Analysis — RFM-arvutused ja kliendisegmendid | **Helen** |
# | **Roll D** | Visualization — visualiseerimine ja äritõlgendus | **Kalju** |
#
# Koondfailis on Roll A, Roll B ja Roll C originaaltööd lisatud muutmata kujul. Roll D lisab oma töö lõpus olevasse Roll D struktuuri.

# %% [markdown]
# # Roll A — Data Loading
#
# **Vastutaja: Natalia**
#
# Allpool on Roll A parandatud originaaltöö muutmata kujul.

# %%
#ROLL A - Data Loading (Andmete laadimine)_NATALIA

import os
import pandas as pd
from dotenv import load_dotenv, find_dotenv
from supabase import create_client

# 1. Lae muutujad .env failist
load_dotenv(find_dotenv())

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

# 2. Ühendamine ja andmete laadimine Supabase'ist
# 2.1 Funktsioon, mis laadib Supabase'ist kõik read
# Supabase tagastab ühe päringuga maksimaalselt 1000 rida,
# seetõttu laaditakse andmed 1000 rea kaupa.
def get_data(tabel_name):
    data = []
    page_size = 1000
    page = 0

    while True:
        response = (supabase.table(tabel_name).select("*").range(page * page_size,(page + 1) * page_size - 1)
            .execute())
        data.extend(response.data)
        if len(response.data) < page_size:
            break
        page += 1
    return pd.DataFrame(data)

# 2.2. Proovime andmed Supabase'ist laadida
try:
    # Loome ühenduse Supabase'iga
    supabase = create_client(url, key)

    # Laeme kõik müügi- ja kliendiread
    df_sales = get_data("sales")
    df_customers = get_data("customers")

    print("✅ Andmed laeti edukalt Supabase'ist!")
    print("Sales tabeli shape:", df_sales.shape)
    print("Customers tabeli shape:", df_customers.shape)

# 2.3. Kui Supabase ei tööta, proovime CSV-faile
except Exception as e:
    print(f"⚠️ Supabase ei toiminud ({e}), laadime lokaalsetest CSV-failidest...")
    df_sales = pd.read_csv("sales.csv")
    df_customers = pd.read_csv("customers.csv")
    print("✅ Andmed laeti CSV-failidest!\n")
    print("Sales tabeli shape:", df_sales.shape)
    print("Customers tabeli shape:", df_customers.shape)
# Out:
# ✅ Andmed laeti edukalt Supabase'ist!
# Sales tabeli shape: (10118, 12)
# Customers tabeli shape: (3150, 9)

# %%
# 3. Sales tabeli kontroll
print("--- 1. SALES TABEL ---")
print("Sales tabeli shape:", df_sales.shape)
print(df_sales.head())
# Out:
# --- 1. SALES TABEL ---
# Sales tabeli shape: (10118, 12)
#       id  sale_id        invoice_id            sale_date  customer_id  \
# 0  45703        1  INV-202301-00001  2023-01-10T00:00:00       2588.0
# 1  45704        2  INV-202301-00002  2023-01-16T00:00:00       4338.0
# 2  45705        3  INV-202301-00003  2023-01-05T00:00:00       4673.0
# 3  45706        4  INV-202301-00004  2023-01-02T00:00:00       4677.0
# 4  45707        5  INV-202301-00005  2023-01-13T00:00:00       2390.0
#
#    product_id  quantity  unit_price  total_price channel store_location  \
# 0        1274         2      234.79       469.58    pood        Tallinn
# 1        1207         2      241.13       482.26    pood          Pärnu
# 2        1264         1      258.46       221.19    pood          Pärnu
# 3        1341         3       45.21       135.63    pood          Tartu
# 4        1284         1       99.57        99.57    pood          Tartu
#
#   payment_method
# 0          kaart
# 1      järelmaks
# 2      järelmaks
# 3       sularaha
# 4          kaart

# %%
# 4. Customers tabeli kontroll
print("\n--- 2. CUSTOMERS TABEL ---")
print("Customers tabeli shape:", df_customers.shape)
print(df_customers.head())
# Out:
# --- 2. CUSTOMERS TABEL ---
# Customers tabeli shape: (3150, 9)
#    customer_id first_name last_name email           phone     city  \
# 0         2637       Reet      Nurk   NaN  +372 5354 8280  Tallinn
# 1         2723       Reet    Kuusik   NaN  +372 5603 8700    Tartu
# 2         2784       Mart      Pihl   NaN  +372 5536 5657  Tallinn
# 3         3404       Maie    Tammik   NaN  +372 5291 9215  Tallinn
# 4         4278       Nele      Orav   NaN  +372 8700 9137  Tallinn
#
#   registration_date loyalty_tier  birth_year
# 0        2022-12-09         gold        1976
# 1        2023-04-09          NaN        1998
# 2        2022-10-30         gold        1989
# 3        2020-03-26          NaN        2000
# 4        2024-05-10          NaN        1992

# %%
# 5. Liidame tabelid
df = pd.merge(df_sales, df_customers, on="customer_id", how="left")

# %%
print("\n--- 3. LIIDATUD DATAFRAME (df) ---")
print("Liidatud tabeli shape:", df.shape)
print("\nVeergude tüübid (dtypes):")
print(df.dtypes)
print("\nEsimesed 5 rida (head):")
print(df.head())
# Out:
# --- 3. LIIDATUD DATAFRAME (df) ---
# Liidatud tabeli shape: (10118, 20)
#
# Veergude tüübid (dtypes):
# id                     int64
# sale_id                int64
# invoice_id               str
# sale_date                str
# customer_id          float64
# product_id             int64
# quantity               int64
# unit_price           float64
# total_price          float64
# channel                  str
# store_location           str
# payment_method           str
# first_name               str
# last_name                str
# email                    str
# phone                    str
# city                     str
# registration_date        str
# loyalty_tier             str
# birth_year           float64
# dtype: object
#
# Esimesed 5 rida (head):
#       id  sale_id        invoice_id            sale_date  customer_id  \
# 0  45703        1  INV-202301-00001  2023-01-10T00:00:00       2588.0
# 1  45704        2  INV-202301-00002  2023-01-16T00:00:00       4338.0
# 2  45705        3  INV-202301-00003  2023-01-05T00:00:00       4673.0
# 3  45706        4  INV-202301-00004  2023-01-02T00:00:00       4677.0
# 4  45707        5  INV-202301-00005  2023-01-13T00:00:00       2390.0
#
#    product_id  quantity  unit_price  total_price channel store_location  \
# 0        1274         2      234.79       469.58    pood        Tallinn
# 1        1207         2      241.13       482.26    pood          Pärnu
# 2        1264         1      258.46       221.19    pood          Pärnu
# 3        1341         3       45.21       135.63    pood          Tartu
# 4        1284         1       99.57        99.57    pood          Tartu
#
#   payment_method first_name last_name                 email           phone  \
# 0          kaart      Hille      Paju                   NaN  +372 5429 0294
# 1      järelmaks      Merle      Luik    merle.luik@mail.ee  +372 5150 1812
# 2      järelmaks      Liina      Saar  liina.saar@gmail.com  +372 8809 7990
# 3       sularaha       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888
# 4          kaart      Triin      Lill   triin.lill@telia.ee  +372 5378 0596
#
#       city registration_date loyalty_tier  birth_year
# 0  Tallinn        2022-07-28       bronze      1997.0
# 1  Tallinn        2020-09-22          NaN      1996.0
# 2  Tallinn        2020-03-31       silver      1973.0
# 3    Narva        2021-10-08         gold      1972.0
# 4    Tartu        2021-04-09          NaN      1996.0

# %%
# Seadistame Pandas'i kuvama kõiki veerge
pd.set_option('display.max_columns', None)

print("--- LIIDATUD TABELI ESIMESED READ ---")
display(df.head())

print("\n--- ANDMETE ÜLDULEVAATUS ---")
df.info()
# Out:
# --- LIIDATUD TABELI ESIMESED READ ---
#       id  sale_id        invoice_id            sale_date  customer_id  \
# 0  45703        1  INV-202301-00001  2023-01-10T00:00:00       2588.0
# 1  45704        2  INV-202301-00002  2023-01-16T00:00:00       4338.0
# 2  45705        3  INV-202301-00003  2023-01-05T00:00:00       4673.0
# 3  45706        4  INV-202301-00004  2023-01-02T00:00:00       4677.0
# 4  45707        5  INV-202301-00005  2023-01-13T00:00:00       2390.0
#
#    product_id  quantity  unit_price  total_price channel store_location  \
# 0        1274         2      234.79       469.58    pood        Tallinn
# 1        1207         2      241.13       482.26    pood          Pärnu
# 2        1264         1      258.46       221.19    pood          Pärnu
# 3        1341         3       45.21       135.63    pood          Tartu
# 4        1284         1       99.57        99.57    pood          Tartu
#
#   payment_method first_name last_name                 email           phone  \
# 0          kaart      Hille      Paju                   NaN  +372 5429 0294
# 1      järelmaks      Merle      Luik    merle.luik@mail.ee  +372 5150 1812
# 2      järelmaks      Liina      Saar  liina.saar@gmail.com  +372 8809 7990
# 3       sularaha       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888
# 4          kaart      Triin      Lill   triin.lill@telia.ee  +372 5378 0596
#
#       city registration_date loyalty_tier  birth_year
# 0  Tallinn        2022-07-28       bronze      1997.0
# 1  Tallinn        2020-09-22          NaN      1996.0
# 2  Tallinn        2020-03-31       silver      1973.0
# 3    Narva        2021-10-08         gold      1972.0
# 4    Tartu        2021-04-09          NaN      1996.0
# --- ANDMETE ÜLDULEVAATUS ---
# <class 'pandas.DataFrame'>
# RangeIndex: 10118 entries, 0 to 10117
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10118 non-null  int64
#  1   sale_id            10118 non-null  int64
#  2   invoice_id         10118 non-null  str
#  3   sale_date          10118 non-null  str
#  4   customer_id        9130 non-null   float64
#  5   product_id         10118 non-null  int64
#  6   quantity           10118 non-null  int64
#  7   unit_price         10118 non-null  float64
#  8   total_price        10118 non-null  float64
#  9   channel            10118 non-null  str
#  10  store_location     6656 non-null   str
#  11  payment_method     10118 non-null  str
#  12  first_name         9130 non-null   str
#  13  last_name          9130 non-null   str
#  14  email              8174 non-null   str
#  15  phone              9130 non-null   str
#  16  city               9130 non-null   str
#  17  registration_date  9130 non-null   str
#  18  loyalty_tier       5458 non-null   str
#  19  birth_year         9130 non-null   float64
# dtypes: float64(4), int64(4), str(12)
# memory usage: 2.6 MB

# %% [markdown]
# # Roll B — Data Cleaning
#
# **Vastutaja: Olga**

# %%
print(df.shape)
# Out:
# (10118, 20)

# %%
print("Esialgne shape:", df.shape)

# Duplikaadid
print("Duplikaadid:", df.duplicated(subset=['invoice_id']).sum())
df = df.drop_duplicates(subset=['invoice_id'], keep='first')

# NULL väärtused
print("\nNULL väärtused:")
print(df.isnull().sum())

df = df.dropna(subset=['customer_id', 'sale_date', 'total_price'])

# Kuupäev datetime-ks
df['sale_date'] = pd.to_datetime(df['sale_date'])

# Negatiivsed hinnad
df = df[df['total_price'] > 0]

# Puhastusraport
print("\n===== PUHASTUSRAPORT =====")
print("Lõplik shape:", df.shape)
print("Unikaalseid kliente:", df['customer_id'].nunique())
print("Kuupäevavahemik:",
      df['sale_date'].min(),
      "kuni",
      df['sale_date'].max())

df.head()
# Out:
# Esialgne shape: (10118, 20)
# Duplikaadid: 0
#
# NULL väärtused:
# id                      0
# sale_id                 0
# invoice_id              0
# sale_date               0
# customer_id           988
# product_id              0
# quantity                0
# unit_price              0
# total_price             0
# channel                 0
# store_location       3462
# payment_method          0
# first_name            988
# last_name             988
# email                1944
# phone                 988
# city                  988
# registration_date     988
# loyalty_tier         4660
# birth_year            988
# dtype: int64
#
# ===== PUHASTUSRAPORT =====
# Lõplik shape: (8950, 20)
# Unikaalseid kliente: 2540
# Kuupäevavahemik: 2023-01-01 00:00:00 kuni 2026-06-28 00:00:00
#       id  sale_id        invoice_id  sale_date  customer_id  product_id  \
# 0  45703        1  INV-202301-00001 2023-01-10       2588.0        1274
# 1  45704        2  INV-202301-00002 2023-01-16       4338.0        1207
# 2  45705        3  INV-202301-00003 2023-01-05       4673.0        1264
# 3  45706        4  INV-202301-00004 2023-01-02       4677.0        1341
# 4  45707        5  INV-202301-00005 2023-01-13       2390.0        1284
#
#    quantity  unit_price  total_price channel store_location payment_method  \
# 0         2      234.79       469.58    pood        Tallinn          kaart
# 1         2      241.13       482.26    pood          Pärnu      järelmaks
# 2         1      258.46       221.19    pood          Pärnu      järelmaks
# 3         3       45.21       135.63    pood          Tartu       sularaha
# 4         1       99.57        99.57    pood          Tartu          kaart
#
#   first_name last_name                 email           phone     city  \
# 0      Hille      Paju                   NaN  +372 5429 0294  Tallinn
# 1      Merle      Luik    merle.luik@mail.ee  +372 5150 1812  Tallinn
# 2      Liina      Saar  liina.saar@gmail.com  +372 8809 7990  Tallinn
# 3       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888    Narva
# 4      Triin      Lill   triin.lill@telia.ee  +372 5378 0596    Tartu
#
#   registration_date loyalty_tier  birth_year
# 0        2022-07-28       bronze      1997.0
# 1        2020-09-22          NaN      1996.0
# 2        2020-03-31       silver      1973.0
# 3        2021-10-08         gold      1972.0
# 4        2021-04-09          NaN      1996.0

# %%
print("\n--- 3. LIIDATUD DATAFRAME (df) ---")
print("Liidatud tabeli shape:", df.shape)
print("\nVeergude tüübid (dtypes):")
print(df.dtypes)
print("\nEsimesed 5 rida (head):")
print(df.head())
# Out:
# --- 3. LIIDATUD DATAFRAME (df) ---
# Liidatud tabeli shape: (8950, 20)
#
# Veergude tüübid (dtypes):
# id                            int64
# sale_id                       int64
# invoice_id                      str
# sale_date            datetime64[us]
# customer_id                 float64
# product_id                    int64
# quantity                      int64
# unit_price                  float64
# total_price                 float64
# channel                         str
# store_location                  str
# payment_method                  str
# first_name                      str
# last_name                       str
# email                           str
# phone                           str
# city                            str
# registration_date               str
# loyalty_tier                    str
# birth_year                  float64
# dtype: object
#
# Esimesed 5 rida (head):
#       id  sale_id        invoice_id  sale_date  customer_id  product_id  \
# 0  45703        1  INV-202301-00001 2023-01-10       2588.0        1274
# 1  45704        2  INV-202301-00002 2023-01-16       4338.0        1207
# 2  45705        3  INV-202301-00003 2023-01-05       4673.0        1264
# 3  45706        4  INV-202301-00004 2023-01-02       4677.0        1341
# 4  45707        5  INV-202301-00005 2023-01-13       2390.0        1284
#
#    quantity  unit_price  total_price channel store_location payment_method  \
# 0         2      234.79       469.58    pood        Tallinn          kaart
# 1         2      241.13       482.26    pood          Pärnu      järelmaks
# 2         1      258.46       221.19    pood          Pärnu      järelmaks
# 3         3       45.21       135.63    pood          Tartu       sularaha
# 4         1       99.57        99.57    pood          Tartu          kaart
#
#   first_name last_name                 email           phone     city  \
# 0      Hille      Paju                   NaN  +372 5429 0294  Tallinn
# 1      Merle      Luik    merle.luik@mail.ee  +372 5150 1812  Tallinn
# 2      Liina      Saar  liina.saar@gmail.com  +372 8809 7990  Tallinn
# 3       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888    Narva
# 4      Triin      Lill   triin.lill@telia.ee  +372 5378 0596    Tartu
#
#   registration_date loyalty_tier  birth_year
# 0        2022-07-28       bronze      1997.0
# 1        2020-09-22          NaN      1996.0
# 2        2020-03-31       silver      1973.0
# 3        2021-10-08         gold      1972.0
# 4        2021-04-09          NaN      1996.0

# %%
# Seadistame Pandas'i kuvama kõiki veerge
pd.set_option('display.max_columns', None)

print("--- LIIDATUD TABELI ESIMESED READ ---")
display(df.head())

print("\n--- ANDMETE ÜLDULEVAATUS ---")
df.info()
# Out:
# --- LIIDATUD TABELI ESIMESED READ ---
#       id  sale_id        invoice_id  sale_date  customer_id  product_id  \
# 0  45703        1  INV-202301-00001 2023-01-10       2588.0        1274
# 1  45704        2  INV-202301-00002 2023-01-16       4338.0        1207
# 2  45705        3  INV-202301-00003 2023-01-05       4673.0        1264
# 3  45706        4  INV-202301-00004 2023-01-02       4677.0        1341
# 4  45707        5  INV-202301-00005 2023-01-13       2390.0        1284
#
#    quantity  unit_price  total_price channel store_location payment_method  \
# 0         2      234.79       469.58    pood        Tallinn          kaart
# 1         2      241.13       482.26    pood          Pärnu      järelmaks
# 2         1      258.46       221.19    pood          Pärnu      järelmaks
# 3         3       45.21       135.63    pood          Tartu       sularaha
# 4         1       99.57        99.57    pood          Tartu          kaart
#
#   first_name last_name                 email           phone     city  \
# 0      Hille      Paju                   NaN  +372 5429 0294  Tallinn
# 1      Merle      Luik    merle.luik@mail.ee  +372 5150 1812  Tallinn
# 2      Liina      Saar  liina.saar@gmail.com  +372 8809 7990  Tallinn
# 3       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888    Narva
# 4      Triin      Lill   triin.lill@telia.ee  +372 5378 0596    Tartu
#
#   registration_date loyalty_tier  birth_year
# 0        2022-07-28       bronze      1997.0
# 1        2020-09-22          NaN      1996.0
# 2        2020-03-31       silver      1973.0
# 3        2021-10-08         gold      1972.0
# 4        2021-04-09          NaN      1996.0
# --- ANDMETE ÜLDULEVAATUS ---
# <class 'pandas.DataFrame'>
# Index: 8950 entries, 0 to 10116
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8950 non-null   int64
#  1   sale_id            8950 non-null   int64
#  2   invoice_id         8950 non-null   str
#  3   sale_date          8950 non-null   datetime64[us]
#  4   customer_id        8950 non-null   float64
#  5   product_id         8950 non-null   int64
#  6   quantity           8950 non-null   int64
#  7   unit_price         8950 non-null   float64
#  8   total_price        8950 non-null   float64
#  9   channel            8950 non-null   str
#  10  store_location     5896 non-null   str
#  11  payment_method     8950 non-null   str
#  12  first_name         8950 non-null   str
#  13  last_name          8950 non-null   str
#  14  email              8011 non-null   str
#  15  phone              8950 non-null   str
#  16  city               8950 non-null   str
#  17  registration_date  8950 non-null   str
#  18  loyalty_tier       5351 non-null   str
#  19  birth_year         8950 non-null   float64
# dtypes: datetime64[us](1), float64(4), int64(4), str(11)
# memory usage: 2.2 MB

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # Nädal 7 — Roll C: RFM kliendisegmenteerimine
#
# **Vastutaja: Helen**
#
# ## Roll ja töö ulatus
#
# **Roll C — RFM Analysis**
#
# - Recency, Frequency ja Monetary arvutamine;
# - R-, F- ja M-skooride määramine;
# - RFM-koondskoori loomine;
# - baastaseme kliendisegmentide määramine;
# - segmentide kokkuvõte;
# - edasijõudnute taseme kaalutud skoor, detailsemad segmendid ja CSV eksport.
#
# ### Sisend
#
# Roll B annab puhastatud pandas DataFrame'i nimega `df`.

# %% [markdown]
# ## 1. Teegi import ja Roll B sisend
#
# Pandas imporditakse RFM-arvutuste tegemiseks.
#
# > Enne järgmiste lahtrite käivitamist peab Roll A andmed imporditud ning roll B puhastatud DataFrame `df` olema notebook'is olemas.

# %%
import pandas as pd

# Roll B väljund:
# df = puhastatud müügi- ja kliendiandmete DataFrame

df.head()
# Out:
#       id  sale_id        invoice_id  sale_date  customer_id  product_id  \
# 0  45703        1  INV-202301-00001 2023-01-10       2588.0        1274
# 1  45704        2  INV-202301-00002 2023-01-16       4338.0        1207
# 2  45705        3  INV-202301-00003 2023-01-05       4673.0        1264
# 3  45706        4  INV-202301-00004 2023-01-02       4677.0        1341
# 4  45707        5  INV-202301-00005 2023-01-13       2390.0        1284
#
#    quantity  unit_price  total_price channel store_location payment_method  \
# 0         2      234.79       469.58    pood        Tallinn          kaart
# 1         2      241.13       482.26    pood          Pärnu      järelmaks
# 2         1      258.46       221.19    pood          Pärnu      järelmaks
# 3         3       45.21       135.63    pood          Tartu       sularaha
# 4         1       99.57        99.57    pood          Tartu          kaart
#
#   first_name last_name                 email           phone     city  \
# 0      Hille      Paju                   NaN  +372 5429 0294  Tallinn
# 1      Merle      Luik    merle.luik@mail.ee  +372 5150 1812  Tallinn
# 2      Liina      Saar  liina.saar@gmail.com  +372 8809 7990  Tallinn
# 3       Aili      Pihl   aili.pihl@yahoo.com  +372 8375 4888    Narva
# 4      Triin      Lill   triin.lill@telia.ee  +372 5378 0596    Tartu
#
#   registration_date loyalty_tier  birth_year
# 0        2022-07-28       bronze      1997.0
# 1        2020-09-22          NaN      1996.0
# 2        2020-03-31       silver      1973.0
# 3        2021-10-08         gold      1972.0
# 4        2021-04-09          NaN      1996.0

# %% [markdown]
# ## 2. Baastase — RFM-mõõdikute arvutamine
#
# ### 2.1. Määra viitekuupäev:

# %%
today = pd.to_datetime("2025-02-28")

print("RFM viitekuupäev:", today)
# Out:
# RFM viitekuupäev: 2025-02-28 00:00:00

# %% [markdown]
# ### 2.2. Recency
#
# Recency näitab päevade arvu kliendi viimasest ostust viitekuupäevani.
#
# Madalam Recency väärtus on parem.

# %%
recency = (
    df.groupby("customer_id")["sale_date"]
    .max()
    .reset_index()
)

recency.columns = [
    "customer_id",
    "last_purchase_date"
]

recency["recency_days"] = (
    today - recency["last_purchase_date"]
).dt.days

recency.head()
# Out:
#    customer_id last_purchase_date  recency_days
# 0       2001.0         2024-11-29            91
# 1       2004.0         2024-12-19            71
# 2       2005.0         2024-10-03           148
# 3       2006.0         2023-11-09           477
# 4       2007.0         2025-01-30            29

# %% [markdown]
# ### 2.3. Frequency
#
# Frequency näitab kliendi ostude arvu.

# %%
frequency = (
    df.groupby("customer_id")["sale_id"]
    .count()
    .reset_index()
)

frequency.columns = [
    "customer_id",
    "frequency"
]

frequency.head()
# Out:
#    customer_id  frequency
# 0       2001.0          2
# 1       2004.0          2
# 2       2005.0          4
# 3       2006.0          1
# 4       2007.0          1

# %% [markdown]
# ### 2.4. Monetary
#
# Monetary näitab kliendi kogukulutust.

# %%
monetary = (
    df.groupby("customer_id")["total_price"]
    .sum()
    .reset_index()
)

monetary.columns = [
    "customer_id",
    "monetary_value"
]

monetary.head()
# Out:
#    customer_id  monetary_value
# 0       2001.0          203.92
# 1       2004.0         1198.56
# 2       2005.0          959.60
# 3       2006.0          327.06
# 4       2007.0          318.63

# %% [markdown]
# ### 2.5. RFM-tabeli ühendamine
#
# Recency, Frequency ja Monetary ühendatakse üheks kliendipõhiseks tabeliks.

# %%
rfm = (
    recency[["customer_id", "recency_days"]]
    .merge(
        frequency,
        on="customer_id"
    )
    .merge(
        monetary,
        on="customer_id"
    )
)

rfm.head()
# Out:
#    customer_id  recency_days  frequency  monetary_value
# 0       2001.0            91          2          203.92
# 1       2004.0            71          2         1198.56
# 2       2005.0           148          4          959.60
# 3       2006.0           477          1          327.06
# 4       2007.0            29          1          318.63

# %% [markdown]
# ## 3. Baastase — RFM-skoorid
#
# Iga RFM-mõõdik hinnatakse kvintiilide alusel skaalal 1–5.
#
# - Recency: madalam väärtus saab kõrgema skoori.
# - Frequency: kõrgem väärtus saab kõrgema skoori.
# - Monetary: kõrgem väärtus saab kõrgema skoori.

# %%
rfm["R_score"] = pd.qcut(
    rfm["recency_days"],
    5,
    labels=[5, 4, 3, 2, 1]
)

rfm["F_score"] = pd.qcut(
    rfm["frequency"].rank(method="first"),
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm["M_score"] = pd.qcut(
    rfm["monetary_value"],
    5,
    labels=[1, 2, 3, 4, 5]
)

rfm["R_score"] = rfm["R_score"].astype(int)
rfm["F_score"] = rfm["F_score"].astype(int)
rfm["M_score"] = rfm["M_score"].astype(int)

rfm["RFM_Score"] = (
    rfm["R_score"]
    + rfm["F_score"]
    + rfm["M_score"]
)

rfm.head()
# Out:
#    customer_id  recency_days  frequency  monetary_value  R_score  F_score  \
# 0       2001.0            91          2          203.92        4        1
# 1       2004.0            71          2         1198.56        4        1
# 2       2005.0           148          4          959.60        3        4
# 3       2006.0           477          1          327.06        1        1
# 4       2007.0            29          1          318.63        5        1
#
#    M_score  RFM_Score
# 0        1          6
# 1        4          9
# 2        3         10
# 3        1          3
# 4        1          7

# %% [markdown]
# ## 4. Baastase — viis kliendisegmenti
#
# Juhendi baastaseme segmendid:
#
# | RFM-skoor | Segment |
# |---:|---|
# | 13–15 | VIP Champions |
# | 10–12 | Loyal |
# | 7–9 | Potential |
# | 4–6 | At Risk |
# | 3 | Lost |

# %%
def segment_customer(row):
    if row["RFM_Score"] >= 13:
        return "VIP Champions"
    elif row["RFM_Score"] >= 10:
        return "Loyal"
    elif row["RFM_Score"] >= 7:
        return "Potential"
    elif row["RFM_Score"] >= 4:
        return "At Risk"
    else:
        return "Lost"


rfm["Segment"] = rfm.apply(
    segment_customer,
    axis=1
)

rfm.head()
# Out:
#    customer_id  recency_days  frequency  monetary_value  R_score  F_score  \
# 0       2001.0            91          2          203.92        4        1
# 1       2004.0            71          2         1198.56        4        1
# 2       2005.0           148          4          959.60        3        4
# 3       2006.0           477          1          327.06        1        1
# 4       2007.0            29          1          318.63        5        1
#
#    M_score  RFM_Score    Segment
# 0        1          6    At Risk
# 1        4          9  Potential
# 2        3         10      Loyal
# 3        1          3       Lost
# 4        1          7  Potential

# %% [markdown]
# ## 5. Baastaseme kokkuvõte
#
# Kokkuvõte näitab iga segmendi klientide arvu ja osakaalu.

# %%
segment_summary = (
    rfm["Segment"]
    .value_counts()
    .rename_axis("Segment")
    .reset_index(name="customers")
)

segment_summary["customer_share_pct"] = (
    segment_summary["customers"]
    / len(rfm)
    * 100
)

segment_summary["customer_share_pct"] = (
    segment_summary["customer_share_pct"]
    .round(2)
)

segment_summary
# Out:
#          Segment  customers  customer_share_pct
# 0      Potential        759               29.88
# 1          Loyal        679               26.73
# 2        At Risk        529               20.83
# 3  VIP Champions        455               17.91
# 4           Lost        118                4.65

# %% [markdown]
# ### Baastaseme kvaliteedikontroll
#
# Kontrollitakse juhendis nõutud tingimusi:
#
# - RFM-väärtused on arvutatud;
# - skoorid jäävad vahemikku 1–5;
# - iga klient sai segmendi;
# - kokkuvõte näitab klientide arvu ja osakaalu.

# %%
print("Kliente RFM-tabelis:", len(rfm))
print("Segmendita kliente:", rfm["Segment"].isna().sum())

print("\nSkooride vahemikud:")
print(
    rfm[
        ["R_score", "F_score", "M_score"]
    ].agg(["min", "max"])
)

print(
    "\nKlientide osakaal kokku:",
    round(segment_summary["customer_share_pct"].sum(), 2),
    "%"
)
# Out:
# Kliente RFM-tabelis: 2540
# Segmendita kliente: 0
#
# Skooride vahemikud:
#      R_score  F_score  M_score
# min        1        1        1
# max        5        5        5
#
# Klientide osakaal kokku: 100.0 %

# %% [markdown]
# # Nädal 7 — Roll D: Visualiseerimine
#
# **Vastutaja: Kalju**
#
# ## Roll ja töö ulatus
#
# **Roll D — Visualiseerimine**
#
# - Luua Tulp diagramm mis näitab klientide jaotust gruppide kaupa
# - Luua Hajuvus diagram mis näitab iga kliendi ostusid ajas ning mahus.
# - Luua Sektor diagramm mis näitab top 10 kliendi ostude suhet kogu käibest.
# - Luua kokkuvõtte soovitusteks
#
# ### Sisend
#
# Roll C annab puhastatud DataFrame'id nimega `segment_summary` ja `rfm`.

# %%
import plotly.express as px
import plotly.io as pio
import webbrowser
import pandas as pd

# Sort segments
order = ["VIP Champions", "Loyal", "Potential", "At Risk", "Lost"]
segment_summary["Segment"] = pd.Categorical(segment_summary["Segment"], categories=order, ordered=True)
segment_summary = segment_summary.sort_values("Segment")

fig1 = px.bar(
    segment_summary,
    x="Segment",
    y="customer_share_pct",
    text="customers",
    title="Klientide jaotus",
    labels={"customer_share_pct": "Osakaal (%)", "Segment": "Segment"},
    color="Segment",
    color_discrete_sequence=px.colors.qualitative.Plotly
)

fig1.update_traces(
    texttemplate="%{text} klienti<br>%{y:.1f}%",
    textposition="outside",
    textfont=dict(size=44, color="white", family="Arial, sans-serif"),
    marker=dict(line=dict(width=1, color="white")),
    hoverinfo='none',
    hovertemplate=None
)

fig1.update_layout(
    template="plotly_dark",
    autosize=True,
    margin=dict(l=80, r=80, t=80, b=80),
    title=dict(font=dict(size=60, color="white", family="Arial, sans-serif")),
    xaxis=dict(
        title=dict(text="Segment", font=dict(size=52, color="white", family="Arial, sans-serif")),
        tickfont=dict(size=44, color="white", family="Arial, sans-serif")
    ),
    yaxis=dict(
        title=dict(text="Osakaal (%)", font=dict(size=52, color="white", family="Arial, sans-serif")),
        tickfont=dict(size=44, color="white", family="Arial, sans-serif"),
        ticksuffix="%"
    ),
    showlegend=False
)

# Try multiple renderers, fallback to HTML
renderers = ["vscode", "notebook", "browser"]
for r in renderers:
    try:
        pio.renderers.default = r
        fig1.show(config={'responsive': True})
        print(f"✅ Graph 1 rendered with {r}")
        break
    except Exception as e:
        print(f"❌ {r} failed: {e}")
        continue
else:
    print("⚠️ All renderers failed – opening HTML file...")
    fig1.write_html("graph1.html")
    webbrowser.open("graph1.html")
# Out:
# ✅ Graph 1 rendered with vscode

# %%
import plotly.express as px
import plotly.io as pio
import webbrowser
import sys

# Ensure consistent segment ordering and colors
order = ["VIP Champions", "Loyal", "Potential", "At Risk", "Lost"]
rfm["Segment"] = pd.Categorical(rfm["Segment"], categories=order, ordered=True)
rfm_sorted = rfm.sort_values("Segment")

fig2 = px.scatter(
    rfm_sorted,
    x="recency_days",
    y="monetary_value",
    color="Segment",
    size=rfm_sorted["frequency"] ** 0.5,
    size_max=15,
    hover_data={"frequency": True, "customer_id": True, "monetary_value": ":.2f"},
    title="Aeg viimasest ostust vs ostu maksumus (log skaala)",
    labels={
        "recency_days": "Aeg viimasest ostust (päevad)",
        "monetary_value": "Ostu maksumus (€)"
    },
    color_discrete_sequence=px.colors.qualitative.Plotly,
    log_y=True,
    category_orders={"Segment": order}
)

fig2.update_layout(
    template="plotly_dark",
    autosize=True,
    margin=dict(l=60, r=200, t=80, b=80),
    title=dict(
        text="Aeg viimasest ostust vs ostu maksumus (log skaala)",
        font=dict(size=60, color="white", family="Arial, sans-serif")
    ),
    xaxis=dict(
        title=dict(text="Aeg viimasest ostust (päevad)", font=dict(size=52, color="white", family="Arial, sans-serif")),
        tickfont=dict(size=44, color="white", family="Arial, sans-serif"),
        automargin=True
    ),
    yaxis=dict(
        title=dict(text="Ostu maksumus (€)", font=dict(size=52, color="white", family="Arial, sans-serif")),
        tickfont=dict(size=44, color="white", family="Arial, sans-serif"),
        tickformat=".0f",
        automargin=True
    ),
    legend=dict(
        title=dict(text="Segment", font=dict(size=48, color="white", family="Arial, sans-serif")),
        font=dict(size=44, color="white", family="Arial, sans-serif"),
        orientation="v",
        y=1,
        x=1.02,
        bgcolor="rgba(30,30,30,0.9)"
    ),
    hoverlabel=dict(
        font=dict(size=44, color="white", family="Arial, sans-serif"),
        bgcolor="rgba(30,30,30,0.95)"
    )
)

# Try multiple renderers, fallback to HTML
renderers = ["vscode", "notebook", "browser"]
for r in renderers:
    try:
        pio.renderers.default = r
        fig2.show(config={'responsive': True})
        print(f"✅ Rendered with {r}")
        break
    except Exception as e:
        print(f"❌ {r} failed: {e}")
        continue
else:
    # If all renderers fail, write HTML
    print("⚠️ All renderers failed – opening HTML file...")
    fig2.write_html("graph2.html")
    webbrowser.open("graph2.html")
# Out:
# ✅ Rendered with vscode

# %%
import plotly.express as px
import plotly.io as pio
import webbrowser
import pandas as pd

total_monetary_all = rfm["monetary_value"].sum()
top10_vip = rfm[rfm["Segment"] == "VIP Champions"].nlargest(10, "monetary_value")
top10_sum = top10_vip["monetary_value"].sum()
other_sum = total_monetary_all - top10_sum

pie_data = pd.DataFrame({
    "Category": ["Top 10 VIP Champions", "Other Customers"],
    "Monetary_Value": [top10_sum, other_sum]
})

fig3 = px.pie(
    pie_data,
    values="Monetary_Value",
    names="Category",
    title=f"Top 10 VIP Champions – osakaal kogu müügikäibest<br>(kogu käive: {total_monetary_all:,.0f} €)",
    color="Category",
    color_discrete_sequence=["#FF6B6B", "#4ECDC4"],
    hole=0.3
)

fig3.update_traces(
    textposition="inside",
    textinfo="percent+label",
    textfont=dict(size=36, color="white", family="Arial, sans-serif"),
    hoverinfo='none',
    hovertemplate=None
)

fig3.update_layout(
    template="plotly_dark",
    autosize=True,
    margin=dict(l=60, r=60, t=100, b=60),
    title=dict(font=dict(size=60, color="white", family="Arial, sans-serif")),
    legend=dict(
        title=dict(text="Grupp", font=dict(size=48, color="white", family="Arial, sans-serif")),
        font=dict(size=44, color="white", family="Arial, sans-serif"),
        bgcolor="rgba(30,30,30,0.9)"
    )
)

# Try multiple renderers, fallback to HTML
renderers = ["vscode", "notebook", "browser"]
for r in renderers:
    try:
        pio.renderers.default = r
        fig3.show(config={'responsive': True})
        print(f"✅ Graph 3 rendered with {r}")
        break
    except Exception as e:
        print(f"❌ {r} failed: {e}")
        continue
else:
    print("⚠️ All renderers failed – opening HTML file...")
    fig3.write_html("graph3.html")
    webbrowser.open("graph3.html")
# Out:
# ✅ Graph 3 rendered with vscode

# %% [markdown]
# # Edasijõudnute tase
#
# Juhendi vabatahtlik edasijõudnute osa sisaldab:
#
# 1. Monetary kahekordse kaaluga skoori;
# 2. kuut detailsemat kliendisegmenti;
# 3. segmentide eksporti CSV-failina.

# %% [markdown]
# ## 6. Kaalutud RFM-skoor
#
# Monetary saab kahekordse kaalu, sest kliendi kulutus on Marko jaoks olulisem.
#
# Kaalutud skoor:
#
# `R_score + F_score + 2 × M_score`

# %%
rfm["Weighted_RFM_Score"] = (
    rfm["R_score"]
    + rfm["F_score"]
    + 2 * rfm["M_score"]
)

rfm[
    [
        "customer_id",
        "R_score",
        "F_score",
        "M_score",
        "RFM_Score",
        "Weighted_RFM_Score"
    ]
].head()
# Out:
#    customer_id  R_score  F_score  M_score  RFM_Score  Weighted_RFM_Score
# 0       2001.0        4        1        1          6                   7
# 1       2004.0        4        1        4          9                  13
# 2       2005.0        3        4        3         10                  13
# 3       2006.0        1        1        1          3                   4
# 4       2007.0        5        1        1          7                   8

# %% [markdown]
# ## 7. Detailsemad segmendid
#
# Juhendi edasijõudnute segmendid:
#
# | RFM-skoor | Segment | Tegevus |
# |---:|---|---|
# | 13–15 | VIP Champions | Early access, VIP sooduskoodid |
# | 11–12 | Loyal Customers | Lojaalsusprogramm, preemiad |
# | 9–10 | Regular Customers | Cross-sell kampaaniad |
# | 7–8 | New Customers | Onboarding, welcome-sari |
# | 5–6 | At Risk | Win-back kampaania, personaliseeritud e-mail |
# | 3–4 | Lost | Viimane katse, suur soodustus |

# %%
def assign_advanced_segment(row):
    if row["RFM_Score"] >= 13:
        return "VIP Champions"
    elif row["RFM_Score"] >= 11:
        return "Loyal Customers"
    elif row["RFM_Score"] >= 9:
        return "Regular Customers"
    elif row["RFM_Score"] >= 7:
        return "New Customers"
    elif row["RFM_Score"] >= 5:
        return "At Risk"
    else:
        return "Lost"


rfm["Advanced_Segment"] = rfm.apply(
    assign_advanced_segment,
    axis=1
)

rfm.head()
# Out:
#    customer_id  recency_days  frequency  monetary_value  R_score  F_score  \
# 0       2001.0            91          2          203.92        4        1
# 1       2004.0            71          2         1198.56        4        1
# 2       2005.0           148          4          959.60        3        4
# 3       2006.0           477          1          327.06        1        1
# 4       2007.0            29          1          318.63        5        1
#
#    M_score  RFM_Score    Segment  Weighted_RFM_Score   Advanced_Segment
# 0        1          6    At Risk                   7            At Risk
# 1        4          9  Potential                  13  Regular Customers
# 2        3         10      Loyal                  13  Regular Customers
# 3        1          3       Lost                   4               Lost
# 4        1          7  Potential                   8      New Customers

# %% [markdown]
# ## 8. Edasijõudnute segmentide kokkuvõte

# %%
advanced_segment_summary = (
    rfm["Advanced_Segment"]
    .value_counts()
    .rename_axis("Advanced_Segment")
    .reset_index(name="customers")
)

advanced_segment_summary["customer_share_pct"] = (
    advanced_segment_summary["customers"]
    / len(rfm)
    * 100
)

advanced_segment_summary["customer_share_pct"] = (
    advanced_segment_summary["customer_share_pct"]
    .round(2)
)

advanced_segment_summary
# Out:
#     Advanced_Segment  customers  customer_share_pct
# 0  Regular Customers        512               20.16
# 1      New Customers        511               20.12
# 2      VIP Champions        455               17.91
# 3    Loyal Customers        415               16.34
# 4            At Risk        391               15.39
# 5               Lost        256               10.08

# %% [markdown]
# ## 9. Tulemuste eksport
#
# Juhendi järgi salvestatakse segmendid faili `rfm_segments.csv`, et Marko saaks tulemuse turundusmeeskonnale edastada.

# %%
rfm.to_csv(
    "rfm_segments.csv",
    index=False
)

print("Fail salvestatud: rfm_segments.csv")
# Out:
# Fail salvestatud: rfm_segments.csv

# %% [markdown]
# ## 10. Roll C väljund
#
# Roll C annab Roll D-le edasi DataFrame'i `rfm`, mis sisaldab:
#
# - `customer_id`;
# - `recency_days`;
# - `frequency`;
# - `monetary_value`;
# - R-, F- ja M-skoore;
# - baastaseme RFM-koondskoori ja segmenti;
# - edasijõudnute kaalutud skoori ja detailsemat segmenti.
#
# Roll D kasutab seda tabelit visualiseerimiseks ja äritõlgenduse koostamiseks.

# %% [markdown]
# # Roll D — Visualization
#
# **Vastutaja: Kalju**
#
# Roll D lisab siia visualiseerimise, tulemuste tõlgendamise ja tegevussoovitused.

# %% [markdown]
# ## Roll D tööstruktuur
#
# ### 1. Segmentide jaotus
#
# Lisa visualiseering, mis näitab klientide arvu RFM-segmentide lõikes.
#
# ### 2. Recency ja Monetary võrdlus
#
# Lisa hajuvusdiagramm, mis näitab klientide ostuaktiivsuse ja rahalise väärtuse seost.
#
# ### 3. TOP 10 VIP-klienti
#
# Lisa visualiseering kümnest suurima väärtusega VIP-kliendist.
#
# ### 4. Äritõlgendus Markole
#
# Kirjelda lühidalt:
#
# - mitu VIP-klienti tuvastati;
# - kui suur on VIP-klientide käibeosakaal;
# - mitu klienti kuulub riskisegmenti;
# - milline segment vajab esmast tähelepanu;
# - mida tulemused tähendavad kliendisuhete juhtimise jaoks.
#
# ### 5. Tegevussoovitused
#
# Lisa 2–3 konkreetset andmetel põhinevat soovitust.
